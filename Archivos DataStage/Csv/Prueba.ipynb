# %%
import pandas as pd

# %%
BD = pd.DataFrame({"Manzana": [3,2], "Peras" : [1,4]}, index=["Juan","Pedro"])

# %%
BD
# Out:
#        Manzana  Peras
# Juan         3      1
# Pedro        2      4

# %%
BD.plot.bar()
# Out:
# <Axes: >

# %%
Datos = pd.read_csv("v_D3 abril 2024.csv")
# Out:
# C:\Users\jesus.vargas\AppData\Local\Temp\ipykernel_20656\3576973143.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   Datos = pd.read_csv("v_D3 abril 2024.csv")

# %%
Datos
# Out:
#          NIE TIPO DE ENTREGA CODIGO DE PRESENTACION             CIT NIF  \
# 0      13001              DM                  CIL10  120000020959001829
# 1      13001              DM                  CIL10  120000020959001988
# 2      13001              DM                  CIL10  120000020959001641
# 3      13001              DM                  CIL10  120000020959002101
# 4      13001              DM                  CIL10  120000020959002276
# ...      ...             ...                    ...                 ...
# 66157      3              DT                    TAN          TCE11-1666
# 66158      3              DT                    TAN           TCR4-1172
# 66159      3              DT                    TAN           TCR4-1172
# 66160      3              DT                    TAN           TCR4-1752
# 66161      3              DT                    TAN             CZ89657
#
#        MARCA  IDENTIFICACION  CENTRO POBLADO SECTOR ZONA No Factura  \
# ...
